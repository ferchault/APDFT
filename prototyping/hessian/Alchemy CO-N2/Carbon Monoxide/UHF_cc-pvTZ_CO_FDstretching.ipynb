# %%
from horton import *
import numpy as np
from optimiz import optimiz
from co_scf2 import uhf,rhf,b3lyp

# %%
optimiz(uhf,1.9,[6.,8.],1.e-10,0.5)
# Out:
# ...
#  _ __ _
# / (..) \ Welcome to HORTON 2.1.1!
# \/ || \/
#  |_''_|  HORTON is written and maintained by by Toon Verstraelen (1).
#
#          This version contains contributions from Toon Verstraelen (1), Pawel Tecmer (2),
#          Farnaz Heidar-Zadeh (2), Cristina E. González-Espinoza (2), Matthew Chan (2),
#          Taewon D. Kim (2), Katharina Boguslawski (2), Stijn Fias (3),
#          Steven Vandenbrande (1), Diego Berrocal (2), and Paul W. Ayers (2)
#
#          (1) Center for Molecular Modeling (CMM), Ghent University, Ghent, Belgium.
#          (2) The Ayers Group, McMaster University, Hamilton, Ontario, Canada.
#          (3) General Chemistry (ALGC), Free University of Brussels, Brussels, Belgium.
#
#          More information about HORTON can be found on this website:
#          http://theochem.github.com/horton/
#
#          The purpose of this log file is to track the progress and quality of a
# ...

# %%
def to_cm(k,Mu):
    return (k/Mu)**0.5*centimeter/planck/lightspeed
Mu_CO=periodic['c'].mass*periodic['O'].mass/(periodic['c'].mass+periodic['O'].mass )

# %%
k=(uhf(2.0871210258939117+0.01,[6.,8.])+2*112.78181256090303+uhf(2.0871210258939117-0.01,[6.,8.]))*10000
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd183460c18>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.12055e+01                          1      -93.5098797539988
#    0  1.04422e+01                          2      -97.8728531675847
#    0               1.000e+00    0.5724310  2 E                        -5.5060509
#    1  3.36826e+00                          3     -111.8304063157339
# ...

# %%
print k, to_cm(k,Mu_CO)
# Out:
# 1.5259547791401928 2424.361881270297

# %% [markdown]
# How much 2nd derivative finite difference changes with respect to the place taken?

# %%
a=uhf(2.+0.01,[6.,8.])
b=uhf(2.,[6.,8.])
c=uhf(2.-0.01,[6.,8.])
k=(a-2*b+c)*10000
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd183460ef0>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.14931e+01                          1      -93.1294926781561
#    0  1.05255e+01                          2      -97.7717379218667
#    0               1.000e+00    0.5773452  2 E                        -5.3608797
#    1  3.30606e+00                          3     -111.9484725511528
# ...

# %%
print a,b,c
# Out:
# -112.77683273434099 -112.77537924034502 -112.77371867976524

# %%
a=uhf(2.+0.1,[6.,8.])
b=uhf(2.,[6.,8.])
c=uhf(2.-0.1,[6.,8.])
k=(a-2*b+c)*100
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd183460e20>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.11964e+01                          1      -93.5214996850096
#    0  1.04379e+01                          2      -97.8747281817643
#    0               1.000e+00    0.5722577  2 E                        -5.5113935
#    1  3.36989e+00                          3     -111.8261999739217
# ...

# %% [markdown]
# So the finite difference method applied on the minimum give the result founded on the bibliography http://www.pitt.edu/~jordan/chem3430/vibrationII.pdf  (2424 vs 2426.6 cm-1), thought the same procedure when applied to a point less then .1 bohr apart of the minimum give a very different result (2836 cm-1)

# %%
a=uhf(2.06+0.01,[6.,8.])
b=uhf(2.06,[6.,8.])
c=uhf(2.06-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da120>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.12930e+01                          1      -93.3975135087478
#    0  1.04775e+01                          2      -97.8508218360750
#    0               1.000e+00    0.5740329  2 E                        -5.4573276
#    1  3.35145e+00                          3     -111.8692613267229
# ...

# %% [markdown]
# for f.d. at 2.06 bohr
# -112.78158428444861 -112.7812328736942 -112.78071346948195
# 1.6799345782203545 2543.740471011323

# %%
a=uhf(2.07+0.01,[6.,8.])
b=uhf(2.07,[6.,8.])
c=uhf(2.07-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da1f0>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.12605e+01                          1      -93.4395614083677
#    0  1.04654e+01                          2      -97.8598813000161
#    0               1.000e+00    0.5734490  2 E                        -5.4749470
#    1  3.35794e+00                          3     -111.8551100807128
# ...

# %% [markdown]
# for f.d at 2.07bohr
# -112.78177353129796 -112.78158428444861 -112.7812328736942
# 1.6216390507395317 2499.2155367652435

# %%
a=uhf(2.08+0.01,[6.,8.])
b=uhf(2.08,[6.,8.])
c=uhf(2.08-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da328>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.12283e+01                          1      -93.4808867467388
#    0  1.04522e+01                          2      -97.8678401775969
#    0               1.000e+00    0.5728571  2 E                        -5.4929735
#    1  3.36409e+00                          3     -111.8407485932629
# ...

# %% [markdown]
# for f.d at 2.08 bohr
#
# -112.78180626484749 -112.78177353129765 -112.78158428444874
#
# 1.5651329906063438 2455.2868505050037

# %%
a=uhf(2.09+0.01,[6.,8.])
b=uhf(2.09,[6.,8.])
c=uhf(2.09-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da460>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.11964e+01                          1      -93.5214996850095
#    0  1.04379e+01                          2      -97.8747281817642
#    0               1.000e+00    0.5722577  2 E                        -5.5113935
#    1  3.36989e+00                          3     -111.8261999739216
# ...

# %% [markdown]
# for f.d at 2.09 bohr
# -112.78168796236096 -112.78180626484749 -112.78177353129765
#
# 1.510360363710106 2411.9422493195993

# %%
a=uhf(2.1+0.01,[6.,8.])
b=uhf(2.1,[6.,8.])
c=uhf(2.1-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da668>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.11647e+01                          1      -93.5614104390126
#    0  1.04225e+01                          2      -97.8805752189777
#    0               1.000e+00    0.5716513  2 E                        -5.5301931
#    1  3.37534e+00                          3     -111.8114872659846
# ...

# %% [markdown]
# for f.d. at 2.1 bohr
#
# -112.78142393318453 -112.7816879623609 -112.78180626484718
#
# 1.4572669010703976 2369.169676990969

# %%
a=uhf(2.11+0.01,[6.,8.])
b=uhf(2.11,[6.,8.])
c=uhf(2.11-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd17fc7a668>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.11332e+01                          1      -93.6006292689844
#    0  1.04061e+01                          2      -97.8854112997575
#    0               1.000e+00    0.5710384  2 E                        -5.5493581
#    1  3.38042e+00                          3     -111.7966333556618
# ...

# %% [markdown]
# for f.d at 2.11 bohr:
#
# -112.781019323991 -112.78142393318453 -112.7816879623609
#
# 1.4058001714545298 2326.9572839836533

# %%
a=uhf(2.12+0.01,[6.,8.])
b=uhf(2.12,[6.,8.])
c=uhf(2.12-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da808>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.11021e+01                          1      -93.6391664691306
#    0  1.03886e+01                          2      -97.8892664544667
#    0               1.000e+00    0.5704192  2 E                        -5.5688743
#    1  3.38513e+00                          3     -111.7816608803116
# ...

# %% [markdown]
# for f.d at 2.12 bohr:
#
#     -112.78047912387277 -112.78101932399107 -112.78142393318402
#
#     1.355909253675236 2285.2931999851758

# %%
a=uhf(2.13+0.01,[6.,8.])
b=uhf(2.13,[6.,8.])
c=uhf(2.13-0.01,[6.,8.])
k=(a-2*b+c)*10000
print a,b,c
print k,to_cm(k,Mu_CO)
# Out:
# Initialized: <horton.gbasis.cext.GOBasis object at 0x7fd1833da940>
#   Number of basis functions         : 60
#   Number of normalization constants : 110
#   Maximum shell type                : 3
#   Center     0 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#   Center     1 :  S8 S8 S1 S1 P3 P1 P1 Dp1 Dp1 Fp1
#
# Performing a core Hamiltonian guess.
#
# Starting restricted closed-shell EDIIS+DIIS-SCF
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iter         Error        CN         Last nv Method          Energy       Change
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    0  1.10712e+01                          1      -93.6770323571280
#    0  1.03701e+01                          2      -97.8921706545175
#    0               1.000e+00    0.5697945  2 E                        -5.5887273
#    1  3.38947e+00                          3     -111.7665921372370
# ...

# %% [markdown]
# for f.d at 2.13 bohr:
# -112.77980816925245 -112.78047912387277 -112.78101932399107
# 1.3075450200972227 2244.1658045616923

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xax=np.linspace(2.06,2.13,8)
print xax
# Out:
# [2.06 2.07 2.08 2.09 2.1  2.11 2.12 2.13]

# %%
import matplotlib.pyplot as plt
xax=np.linspace(2.06,2.13,8)
potential=[-112.78047912387277,-112.78101932399107,-112.78142393318453,-112.7816879623609,-112.78180626484718,-112.78177353129796,-112.78158428444861,-112.7812328736942]
potential.reverse()
exp_nu=[2543.740471011323,2499.2155367652435,2455.2868505050037,2411.9422493195993,2369.169676990969,2326.9572839836533,2285.2931999851758,2244.1658045616923]
plt.subplot(2,1,1)
plt.plot(xax,potential)
plt.subplot(2,1,2)
plt.plot(xax,exp_nu)

# %% [markdown]
# error of 42 cm-1 per 1/100 bohr away from minimum.
# Good linearity? any reason for this?
