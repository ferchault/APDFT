# %%
import matplotlib
from matplotlib import pyplot

# %%
matplotlib.rc('text', usetex = True)
params= {'text.latex.preamble' : [r'\usepackage{amsmath}']}
pyplot.rcParams.update(params)

pyplot.plot([0,1],[0,1])

pyplot.title(r'$f(x)=\left\lVert \Delta \rho \right\rVert $ ' )

pyplot.show()
