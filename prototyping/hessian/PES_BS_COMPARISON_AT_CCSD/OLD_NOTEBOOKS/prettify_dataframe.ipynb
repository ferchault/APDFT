# %%
import pandas as pd

# %%
STO_3G=pd.read_pickle('./data/STO_3G')
STO_6G=pd.read_pickle('./data/STO_6G')
_321G=pd.read_pickle('./data/321G')
_631G=pd.read_pickle('./data/631G')
cc_pVTZ=pd.read_pickle('./data/cc_pVTZ')
aug_cc_pVQZ=pd.read_pickle('./data/aug_cc_pVQZ')
def2_TZVP=pd.read_pickle('./data/def2_TZVP')
def2_QZVPP=pd.read_pickle('./data/def2_QZVPP')

# %%
STO_3G=STO_3G[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
STO_3G["$\Delta E_{\text{BS}}$"]=STO_3G.e_at_ref_bs-STO_3G.e_ccsd 
STO_3G=STO_3G.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
STO_3G[:1]
# Out:
#   Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0     sto3G       HAl   HeMg         0          1.3         3.368281
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -195.799703         -196.696725        -198.025411
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.225708                   0.897022
#
#    $\Delta E_{\text{BS}}$
# 0                1.328686

# %%
STO_6G=STO_6G[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
STO_6G["$\Delta E_{\text{BS}}$"]=STO_6G.e_at_ref_bs-STO_6G.e_ccsd 
STO_6G=STO_6G.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
STO_6G[:1]
# Out:
#   Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0     sto6G       HAl   HeMg         0          1.3         3.399042
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -197.224951         -198.200671        -199.748352
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.523401                    0.97572
#
#    $\Delta E_{\text{BS}}$
# 0                1.547681

# %%
_321G=_321G[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
_321G["$\Delta E_{\text{BS}}$"]=_321G.e_at_ref_bs-_321G.e_ccsd 
_321G=_321G.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
_321G[:1]
# Out:
#   Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0      321G       HAl   HeMg         0          1.3         3.730412
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0          -197.06604         -197.925932          -199.6201
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                      2.55406                   0.859892
#
#    $\Delta E_{\text{BS}}$
# 0                1.694168

# %%
_631G=_631G[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
_631G["$\Delta E_{\text{BS}}$"]=_631G.e_at_ref_bs-_631G.e_ccsd 
_631G=_631G.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
_631G[:1]
# Out:
#   Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0     631G*       HAl   HeMg         0          1.3          3.75576
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -198.156598         -199.055762        -200.788585
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.631987                   0.899164
#
#    $\Delta E_{\text{BS}}$
# 0                1.732823

# %%
cc_pVTZ=cc_pVTZ[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
cc_pVTZ["$\Delta E_{\text{BS}}$"]=cc_pVTZ.e_at_ref_bs-cc_pVTZ.e_ccsd 
cc_pVTZ=cc_pVTZ.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
cc_pVTZ[:1]
# Out:
#   Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0   cc-pVTZ       HAl   HeMg         0          1.3         3.762205
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -198.269808         -199.870264         -200.90067
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.630862                   1.600456
#
#    $\Delta E_{\text{BS}}$
# 0                1.030406

# %%
aug_cc_pVQZ=aug_cc_pVQZ[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
aug_cc_pVQZ["$\Delta E_{\text{BS}}$"]=aug_cc_pVQZ.e_at_ref_bs-aug_cc_pVQZ.e_ccsd 
aug_cc_pVQZ=aug_cc_pVQZ.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
aug_cc_pVQZ[:1]
# Out:
#      Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0  aug-cc-pVQZ       HAl   HeMg         0          1.3         3.742942
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -198.292552         -199.987274        -200.927017
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.634465                   1.694722
#
#    $\Delta E_{\text{BS}}$
# 0                0.939743

# %%
def2_TZVP=def2_TZVP[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
def2_TZVP["$\Delta E_{\text{BS}}$"]=def2_TZVP.e_at_ref_bs-def2_TZVP.e_ccsd 
def2_TZVP=def2_TZVP.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
def2_TZVP[:1]
# Out:
#    Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0  def2-TZVP       HAl   HeMg         0          1.3          3.75217
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -198.264071         -199.911285        -200.900798
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.636727                   1.647214
#
#    $\Delta E_{\text{BS}}$
# 0                0.989513

# %%
def2_QZVPP=def2_QZVPP[list(['basis_set','ref', 'target','alchemy', 'distance', 'delta_rho',  'e_alch','e_at_ref_bs', 'e_ccsd', 
       'abs_err',  'err_alch'])]
def2_QZVPP["$\Delta E_{\text{BS}}$"]=def2_QZVPP.e_at_ref_bs-def2_QZVPP.e_ccsd 
def2_QZVPP=def2_QZVPP.rename(columns={"alchemy": "APDFT$n$","distance": "Bond length","basis_set": "Basis set",\
                      "e_alch":"$E^{\text{APDFT}}$","e_ccsd":"$E^{\text{CCSD}}$","ref":"Reference","target":"Target",\
                      "abs_err":"$|\Delta E_{\text{APDFT}}|$","delta_rho":"$|\Delta \rho|$",\
                      "e_at_ref_bs":"$ E^{\text{T[R]}}$","err_alch":"$\Delta E_{\text{trunc}}$"})
def2_QZVPP[:1]
# Out:
#     Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0  def2-QZVPP       HAl   HeMg         0          1.3          3.75217
#
#    $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# 0         -198.298417         -200.913466        -200.942816
#
#    $|\Delta E_{\text{APDFT}}|$  $\Delta E_{\text{trunc}}$  \
# 0                     2.644399                   2.615049
#
#    $\Delta E_{\text{BS}}$
# 0                 0.02935

# %%
STO_3G.to_pickle('./STO_3G')
STO_6G.to_pickle('./STO_6G')
_321G.to_pickle('./_321G')
_631G.to_pickle('./_631G')
cc_pVTZ.to_pickle('./cc_pVTZ')
aug_cc_pVQZ.to_pickle('./aug_cc_pVQZ')
def2_TZVP.to_pickle('./def2_TZVP')
def2_QZVPP.to_pickle('./def2_QZVPP')

# %%
STO_3G=pd.read_pickle('./STO_3G')
STO_3G[:15]
# Out:
#    Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0      sto3G       HAl   HeMg         0          1.3         3.368281
# 1      sto3G       HAl   HeMg         1          1.3         3.368281
# 2      sto3G       HAl   HeMg         2          1.3         3.368281
# 3      sto3G       HAl   HeMg         3          1.3         3.368281
# 4      sto3G       HAl   HeMg         4          1.3         3.368281
# 5      sto3G       HAl   HeMg         0          1.4         3.397046
# 6      sto3G       HAl   HeMg         1          1.4         3.397046
# 7      sto3G       HAl   HeMg         2          1.4         3.397046
# 8      sto3G       HAl   HeMg         3          1.4         3.397046
# 9      sto3G       HAl   HeMg         4          1.4         3.397046
# 10     sto3G       HAl   HeMg         0          1.5         3.381955
# 11     sto3G       HAl   HeMg         1          1.5         3.381955
# ...
