# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
log = np.loadtxt('/home/misa/projects/APDFT-CPMD/data/BOMD/ase_NVE/Si8_hc/Si8_nve.log', skiprows=1)

# %%
plt.plot(log[:,0]*1000, log[:,1])
#plt.plot(log[:,0]*1000, log[:,2])

# %%
log[:,1][-1]-log[:,1][0]
# Out:
# -0.0018297961399866836

# %%
6.7e-5/8/50*1000
# Out:
# 0.0001675

# %%
plt.plot(log[:,0]*1000, log[:,3])

# %%
plt.plot(log[:,0]*1000, log[:,4])
