# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
log = np.loadtxt('/home/misa/projects/APDFT-CPMD/data/BOMD/ase/Si8_hc/Si8_nve.log', skiprows=1)

# %%
plt.plot(log[:,0], log[:,1])
plt.plot(log[:,0], log[:,2])

# %%
plt.plot(log[:,0], log[:,3])
