# %%
import sys
sys.path.insert(0, '/home/misa/git_repositories/APDFT/prototyping/apdft-ofdft-cpmd/')

from analyse_MD import drift
from ase import units
import numpy as np
from matplotlib import pyplot as plt

# %%
log = np.loadtxt('/home/misa/projects/APDFT-CPMD/data/CPMD/Si8_dt_1e-3/Si8_dt_1e-3.log', skiprows=1)

# %%
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(1,1)
ax.plot(log[:,0]*1000, log[:,1])
ax.set_xlabel('t (fs)')
ax.set_ylabel('$E_{tot}$ (eV)')
#plt.plot(log[:,0]*1000, log[:,2])
# Out:
# Text(0, 0.5, '$E_{tot}$ (eV)')

# %%
drift(log[:,0]*1000, log[:,1]/units.Ha, 8)
# Out:
# -0.00012320963361674652

# %%
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(1,1)
ax.plot(log[:,0]*1000, log[:,2])
ax.set_xlabel('t (fs)')
ax.set_ylabel('$E_{pot}$ (eV)')
# Out:
# Text(0, 0.5, '$E_{pot}$ (eV)')

# %%
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(1,1)
ax.plot(log[:,0]*1000, log[:,3])
ax.set_xlabel('t (fs)')
ax.set_ylabel('$E_{kin}$ (eV)')
# Out:
# Text(0, 0.5, '$E_{kin}$ (eV)')

# %%
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(1,1)
ax.plot(log[:,0]*1000, log[:,4])
ax.set_xlabel('t (fs)')
ax.set_ylabel('T (K)')
# Out:
# Text(0, 0.5, 'T (K)')
