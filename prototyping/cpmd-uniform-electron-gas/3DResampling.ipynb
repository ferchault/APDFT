# %%
import numpy as np
import scipy.ndimage as snd
import matplotlib.pyplot as plt

# %%
data = np.arange(9).reshape(3, 3).astype(np.float)
#data[0, 2] = 0
plt.imshow(data)

# %%
a = snd.map_coordinates(data, positions, mode='nearest')
plt.imshow(a.reshape(50, 50))

# %%
X, Y = np.mgrid[0:2:50j, 0:2:50j]
positions = np.vstack([X.ravel(), Y.ravel()])

# %%
plt.plot(a[:50])
