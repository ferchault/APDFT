# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
f, axs = plt.subplots(5, 1, figsize=(3, 9), sharex=True)
for nidx, name in enumerate('Boron Carbon Nitrogen Oxygen Fluorine'.split()):
    element = name[0]
    group = df.query("element == @element")
    axs[nidx].plot(group.distance, group.total, 'o-')
    axs[nidx].set_ylabel(name)
    if name == 'Fluorine':
        axs[nidx].set_xlabel('Bond length [$\mathrm{\AA}$]')

# %%
df
# Out:
#     distance  electronic element   nuclear      total
# 0        0.8  -81.434221       O  6.350127 -74.313284
# 1        0.8  -43.935774       C  6.350127 -37.803265
# 2        1.0  -81.434221       O  6.350127 -74.313284
# 3        1.0  -43.935774       C  6.350127 -37.803265
# 4        1.2  -81.434221       O  6.350127 -74.313284
# 5        1.2  -43.935774       C  6.350127 -37.803265
# 6        1.5  -81.434221       O  6.350127 -74.313284
# 7        1.5  -43.935774       C  6.350127 -37.803265
# 8        1.7  -81.434221       O  6.350127 -74.313284
# 9        1.7  -43.935774       C  6.350127 -37.803265
# 10       0.8  -81.434221       O  6.350127 -74.313284
# 11       0.8  -43.935774       C  6.350127 -37.803265
# 12       1.0  -81.434221       O  6.350127 -74.313284
# 13       1.0  -43.935774       C  6.350127 -37.803265
# 14       1.2  -81.434221       O  6.350127 -74.313284
# 15       1.2  -43.935774       C  6.350127 -37.803265
# ...
