# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../mrcc/c20-combinedadjusted.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PBE_T', 'pbe_time', 'target', 'CCSD_T', 'HF_T', 'MP2_T',
#        'ccsd_time', 'hf_time', 'mp2_time', 'PM6_T', 'APDFT0_T', 'APDFT1_T',
#        'bnpairs', 'PBE_A', 'CCSD_A', 'HF_A', 'MP2_A', 'PM6_A', 'APDFT0_A',
#        'APDFT1_A', 'deltaE'],
#       dtype='object')
