# %%
file = []
with open('/home/misa/projects/Atomic-Energies/data/lambdas_complete.txt', 'r') as f:
    for line in f:
        file.append(line.strip('\n')+'/DENSITY.cube')

# %%
'asdf # aer'.split('#')
# Out:
# ['asdf ', ' aer']

# %%
import os
# rename and move cube-files for compound path
np = []
for pc in file:
    path2compound = pc.split('/')[:-3]
    path2compound = '/'.join(path2compound)
    num_ve = pc.split('/')[-2]
    new_path = os.path.join(path2compound, 'cube-files/' + num_ve + '.cube')
    np.append(new_path)

# %%
np[-5:]
# Out:
# ['/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_021324/cube-files/ve_8.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_021324/cube-files/ve_15.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_021324/cube-files/ve_23.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_021324/cube-files/ve_30.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_021324/cube-files/ve_38.cube']

# %%
for i,f in enumerate(file):
    if '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002904/run2/ve_8/DENSITY.cube' == f:
        print(i)
# Out:
# 1160

# %%
file[1161:]
# Out:
# ['/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002904/run4/ve_15/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002904/run0/ve_23/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002904/run1/ve_30/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002904/run0/ve_38/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002908/run3/ve_8/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002908/run1/ve_15/DENSITY.cube',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_002908/run0/ve_23/DENSITY.cube',
# ...

# %%
comps = []
for p in file:
    comps.append(p.split('/')[-3])
comps = list(set(comps))
comps.sort()

# %%
prefix = '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/'
p2c = []
for c in comps:
    p2c.append(prefix+c)

# %%
p2c
# Out:
# ['/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000226',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000277',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000292',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000390',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000543',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000546',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000549',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000806',
#  '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/dsgdb9nsd_000807',
# ...
