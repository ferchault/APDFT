# %%
import sys
sys.path.insert(0, '/scicore/home/lilienfeld/sahre0000/APDFT/prototyping/atomic_energies/')

import utils_qm as uqm

import pandas as pd
import os

# %%
comps = uqm.read_list('/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/tar_files/comps')
ncomps = uqm.read_list('/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/new_comps')

# %%
len(set(ncomps)-set(comps))
# Out:
# 767

# %%
len(ncomps)+len(comps)
# Out:
# 1329

# %%
ncomps2
# Out:
# ['dsgdb9nsd_000229',
#  'dsgdb9nsd_000230',
#  'dsgdb9nsd_000273',
#  'dsgdb9nsd_000276',
#  'dsgdb9nsd_000277',
#  'dsgdb9nsd_000278',
#  'dsgdb9nsd_000291',
#  'dsgdb9nsd_000292',
#  'dsgdb9nsd_000390',
#  'dsgdb9nsd_000543',
#  'dsgdb9nsd_000544',
#  'dsgdb9nsd_000545',
#  'dsgdb9nsd_000546',
#  'dsgdb9nsd_000549',
#  'dsgdb9nsd_000806',
#  'dsgdb9nsd_000807',
#  'dsgdb9nsd_000814',
#  'dsgdb9nsd_000815',
#  'dsgdb9nsd_000822',
#  'dsgdb9nsd_000823',
#  'dsgdb9nsd_000824',
#  'dsgdb9nsd_000829',
#  'dsgdb9nsd_000830',
#  'dsgdb9nsd_000831',
#  'dsgdb9nsd_000833',
#  'dsgdb9nsd_000834',
#  'dsgdb9nsd_000835',
#  'dsgdb9nsd_000836',
#  'dsgdb9nsd_000838',
#  'dsgdb9nsd_000842',
#  'dsgdb9nsd_000843',
#  'dsgdb9nsd_000844',
#  'dsgdb9nsd_000846',
#  'dsgdb9nsd_000847',
#  'dsgdb9nsd_000849',
#  'dsgdb9nsd_000850',
#  'dsgdb9nsd_000853',
#  'dsgdb9nsd_000856',
#  'dsgdb9nsd_000857',
#  'dsgdb9nsd_000858',
#  'dsgdb9nsd_000860',
#  'dsgdb9nsd_000861',
#  'dsgdb9nsd_000862',
# ...

# %%
comps = uqm.read_list('/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/slice_ve38/comps_on_alchemy')

# %%
db = pd.read_pickle('/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/calculation_manager.pd')

# %%
paths = []
for wd in list(db['workdir']):
    paths.append(wd[:-6])

# %%
paths = set(paths)

# %%
for p in paths:
    with open(os.path.join(p, 'smiles'), 'r') as f:
        line = f.readline()
        if line.strip('\n') == 'C':
            print(p)
        elif line.strip('\n') == 'CC':
            print(p)
        elif line.strip('\n') == 'CCC':
            print(p)
        elif line.strip('\n') == 'CCCC':
            print(p)
        elif line.strip('\n') == 'CCCCC':
            print(p)
# Out:
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000138
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000001
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000036
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010

# %%
4*4+10
# Out:
# 26

# %%
for wd in db['workdir']:
    if '/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010' in wd:
        print(wd)
# Out:
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010/ve_03
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010/ve_06
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010/ve_08
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010/ve_11
# /scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000010/ve_14

# %%
uqm.load_obj('/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000138/cube-files/run_info')
# Out:
# {'/scicore/home/lilienfeld/sahre0000/projects/atomic_energies/results/amons/amon_000138/ve_05': 'reasonable density'}
