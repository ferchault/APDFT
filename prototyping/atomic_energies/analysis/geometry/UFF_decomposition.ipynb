# %%
import sys
sys.path.insert(0, '/home/sahre/git_repositories/APDFT/prototyping/atomic_energies/')
import UFF_decomposition as UFFd

import glob
import utils_qm as uqm

from matplotlib import pyplot as plt
import numpy as np

import ase
import ase.visualize

# %%
outfiles = glob.glob('/data/sahre/projects/atomic-energies/data/UFF_energies/butanol_bond/out*')
outfiles.sort()

results = []
for of in outfiles[:6]:
    results.append(UFFd.get_UFF_decomposition(of))

# %%
etot = []
atomic_energies = []
for r in results:
    etot.append(r['e_atomic'].sum())
    atomic_energies.append(r['e_atomic'])

# %%
ase.visualize.view(ase.io.read('/data/sahre/projects/atomic-energies/data/UFF_energies/butanol_bond/d_0.92.xyz'))
# Out:
# <Popen: returncode: None args: ['/home/sahre/opt/miniconda3/envs/qm-tools/bi...>

# %%
results[0]['position']
# Out:
# array([[ 0.466, -1.031, -0.367],
#        [ 0.779,  0.471, -0.289],
#        [-0.452,  1.37 , -0.289],
#        [-0.261, -1.598,  0.859],
#        [-0.158,  2.246, -0.289],
#        [ 1.411, -1.573, -0.501],
#        [-0.127, -1.234, -1.271],
#        [ 1.366,  0.687,  0.613],
#        [ 1.402,  0.762, -1.144],
#        [-1.079,  1.168,  0.594],
#        [-1.067,  1.157, -1.181],
#        [ 0.309, -1.409,  1.777],
#        [-0.397, -2.682,  0.768],
#        [-1.254, -1.154,  0.99 ],
#        [-0.938,  2.821, -0.269]])

# %%
rcoord = [0.92429,
 1.04929,
 1.17429,
 1.29929,
 1.42429,
 1.67429]

# %%
plt.plot(rcoord, np.array(etot)*0.00038, '-o')

# %%
plt.rcParams['font.size'] = 20
for i in range(5):
    plt.plot(rcoord,np.array(atomic_energies)[:,i]*0.00038, '-o',label=i)
plt.xlabel('r(CO) (Ang)')
plt.ylabel('E (Ha)')
plt.legend()
plt.legend(bbox_to_anchor=(1.0, 1.05))

# %%
plt.rcParams['font.size'] = 20
for i in range(5):
    if i != 4 and i != 2:
        plt.plot(rcoord,np.array(atomic_energies)[:,i]*0.00038, '-o',label=i)
plt.xlabel('r(CO) (Ang)')
plt.ylabel('E (Ha)')
plt.legend(bbox_to_anchor=(1.0, 1.05))
