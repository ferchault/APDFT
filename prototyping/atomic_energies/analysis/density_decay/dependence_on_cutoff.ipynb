# %%
import sys
sys.path.insert(0, '/home/misa/APDFT/prototyping/atomic_energies')

from parse_cube_files import CUBE

# %%
p = '/home/misa/APDFT/prototyping/atomic_energies/results/test_calculations/correction_schemes_pbc/H2O_cpmd/ve_6/box10/cutoff_1200/box10_1200.cube'

cube_10_1200 = CUBE(p)

# %%
p0025 = '/home/misa/APDFT/prototyping/atomic_energies/results/test_calculations/correction_schemes_pbc/H2O_cpmd/ve_6/box10/cutoff_0025/box10_0025.cube'
cube_10_0025 = CUBE(p0025)

# %%
cube_10_1200.plot_projection((0,2))

# %%
cube_10_0025.plot_projection((0,2))
